# %% [markdown]
# ## Hello Ho

# %%
import pandas as pd
import numpy as np
from joblib import load
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline

# %%
# Load the lr model back into a variable
loaded_model = load('lrmodel.joblib')

# %%
#importing the test dataset cerated by my friend chatgpt
test_data = pd.read_csv('datasets/life_expectancy_test_data.csv')
test_data = test_data.sample(frac=1, random_state=1)
test_data.head()
# Out:
#      Gender  Height  Weight   BMI Physical_Activity Smoking_Status  \
# 584  Female     145      58  27.4               Low        Current
# 970  Female     163      48  18.2              High          Never
# 701    Male     161      68  26.1               Low          Never
# 619  Female     163      51  19.1            Medium         Former
# 534  Female     161      51  19.8            Medium         Former
#
#     Alcohol_Consumption     Diet Blood_Pressure  Cholesterol  Diabetes  \
# 584                High  Average         Normal        198.1         0
# 970            Moderate  Average         Normal        221.5         0
# 701            Moderate  Average         Normal        195.7         1
# 619            Moderate  Average            Low        159.8         0
# 534            Moderate  Average         Normal        194.7         0
#
#      Hypertension  Heart_Disease  Asthma   Age
# 584             1              0       0  57.2
# 970             0              0       0  86.2
# 701             0              1       0  59.2
# 619             0              0       0  81.6
# 534             0              0       0  84.7

# %%
X_cat= test_data.select_dtypes(include=["object", "string"]).columns
X_num = test_data.select_dtypes(exclude=["object", "string"]).columns

features = test_data.keys()
cat_features_ind =[0,4,5,6,7,8]
X_cat = [features[i] for i in cat_features_ind]
print("categorical:")
print(X_cat)
num_features_ind = [1,2,3,9,10,11,12,13]
X_num = [features[i] for i in num_features_ind]
print("numerical:")
print(X_num)
# Out:
# categorical:
# ['Gender', 'Physical_Activity', 'Smoking_Status', 'Alcohol_Consumption', 'Diet', 'Blood_Pressure']
# numerical:
# ['Height', 'Weight', 'BMI', 'Cholesterol', 'Diabetes', 'Hypertension', 'Heart_Disease', 'Asthma']

# %%
num_transformer = Pipeline(
    steps = [
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())  
    ]
)

cat_transformer = Pipeline(
    steps = [
        ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
        ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
    ]
)
preprocessor = ColumnTransformer(
    transformers = [
        ('num', num_transformer, X_num),
        ('cat', cat_transformer, X_cat)
    ]
)
y = test_data["Age"]
X = preprocessor.fit_transform(test_data)
print(np.shape(X))
# Out:
# (1210, 24)

# %%
predictions = loaded_model.predict(X,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 predictions = loaded_model.predict(X,)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 24 features, but LinearRegression is expecting 25 features as input.

# %%
print(predictions)
# Out:
# [ 9.15297108e+13 -1.00727631e+14  1.48768730e+14 ...  5.42678692e+13
#  -6.09471376e+13  4.38321914e+13]

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error: %.2f" % mean_squared_error(y, predictions))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y, predictions))
# Out:
# Mean squared error: 7457582960826049433996099584.00
# Coefficient of determination: -89320555762148220971515904.00
